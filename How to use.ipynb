# %% [markdown]
# > This assumes all the files are in the same directory

# %% [markdown]
# # Refactored:
# This is the new version of the code works for
# 1. MSR-VTT
# 2. DiDeMo
# 3. ActivityNet
# Just change the paths and variables for the combination you want to test it out.
#
# > This doesn't work for VATEX as it has a different way of loading the dataset.

# %%
# !torchrun --nproc_per_node=3 ensemble_wrapper_msrvtt_activitynet_didemo_t2v.py \
  --sim_paths clip4clip_didemo.npy  GRAM_didemo_tv.npy InternVideo2_didemo.npy  \
  --csv_path descs_ret_test_didemo.csv \
  --video_dir corrected_didemo \
  --num_images 14 \
  --model_name OpenGVLab/InternVL3_5-38B \
  --grid_size 3 \
  --ensemble_mode hard_dup \
  2>&1 | tee logs/for_testing_hard_dup_3x3_38B_t2v_didem.log

# %%
# !torchrun --nproc_per_node=3 ensemble_wrapper_msrvtt_activitynet_didemo_t2v.py \
  --sim_paths InternVideo2_didemo.npy GRAM_didemo_tv.npy clip4clip_didemo.npy \
  --csv_path descs_ret_test_didemo.csv \
  --video_dir corrected_didemo \
  --num_images 14 \
  --model_name OpenGVLab/InternVL3_5-38B \
  --grid_size 3 \
  --ensemble_mode hard_dup \
  2>&1 | tee logs/for_testing_hard_dup_3x3_38B_t2v_didem.log

# %%
# !torchrun --nproc_per_node=3 ensemble_wrapper_msrvtt_activitynet_didemo_t2v.py \
  --sim_paths clip4clip_msrvtt.npy GRAM_msrvtt_tvas.npy InternVideo2_msrvtt.npy \
  --csv_path descs_ret_test_msrvtt.csv \
  --video_dir MSRVTT \
  --num_images 14 \
  --model_name OpenGVLab/InternVL3_5-38B \
  --grid_size 3 \
  --ensemble_mode hard_dup \
  --use_subs \
  --subtitle_json msrvtt_subtitles.json \
  2>&1 | tee logs/for_testing_hard_dup_3x3_38B_t2v_with_subs.log

# %%
# !torchrun --nproc_per_node=3 ensemble_wrapper_msrvtt_activitynet_didemo_t2v.py \
  --sim_paths GRAM_msrvtt_tvas.npy InternVideo2_msrvtt.npy clip4clip_msrvtt.npy   \
  --csv_path descs_ret_test_msrvtt.csv \
  --video_dir MSRVTT \
  --num_images 14 \
  --model_name OpenGVLab/InternVL3_5-38B \
  --grid_size 3 \
  --ensemble_mode hard_dup \
  2>&1 | tee logs/for_testing_hard_dup_3x3_38B_t2v_without_subs_test_gram1.log

# %%
# !torchrun --nproc_per_node=3 ensemble_wrapper_msrvtt_activitynet_didemo_t2v.py \
  --sim_paths InternVideo2_msrvtt.npy clip4clip_msrvtt.npy GRAM_msrvtt_tvas.npy  \
  --csv_path descs_ret_test_msrvtt.csv \
  --video_dir MSRVTT \
  --num_images 14 \
  --model_name OpenGVLab/InternVL3_5-38B \
  --grid_size 3 \
  --ensemble_mode hard_dup \
  2>&1 | tee logs/for_testing_hard_dup_3x3_38B_t2v_without_subs_test_inter1.log

# %%
# !torchrun --nproc_per_node=3 ensemble_wrapper_msrvtt_activitynet_didemo_t2v.py \
  --sim_paths clip4clip_msrvtt.npy GRAM_msrvtt_tvas.npy InternVideo2_msrvtt.npy \
  --csv_path descs_ret_test_msrvtt.csv \
  --video_dir MSRVTT \
  --num_images 14 \
  --model_name OpenGVLab/InternVL3_5-38B \
  --grid_size 3 \
  --ensemble_mode hard_dup \
  2>&1 | tee logs/for_testing_hard_dup_3x3_38B_t2v_without_subs.log

# %%
# !torchrun --nproc_per_node=3 ensemble_wrapper_msrvtt_activitynet_didemo_t2v.py \
  --sim_paths clip4clip_msrvtt.npy GRAM_msrvtt_tvas.npy InternVideo2_msrvtt.npy \
  --csv_path descs_ret_test_msrvtt.csv \
  --video_dir MSRVTT \
  --num_images 14 \
  --model_name OpenGVLab/InternVL3_5-38B \
  --grid_size 3 \
  --ensemble_mode soft \
  2>&1 | tee logs/for_testing_soft_3x3_38B_t2v.log

# %%
# !torchrun --nproc_per_node=3 ensemble_wrapper_msrvtt_activitynet_didemo_t2v.py \
  --sim_paths clip4clip_msrvtt.npy GRAM_msrvtt_tvas.npy InternVideo2_msrvtt.npy VAST_msrvtt.npy \
  --csv_path descs_ret_test_msrvtt.csv \
  --video_dir MSRVTT \
  --num_images 14 \
  --model_name OpenGVLab/InternVL3_5-38B \
  --grid_size 3 \
  --ensemble_mode hard_dup \
  2>&1 | tee logs/for_testing_hard_dup_3x3_38B_t2v.log

# %%
# !torchrun --nproc_per_node=3 ensemble_wrapper_msrvtt_activitynet_didemo_t2v.py \
  --sim_paths clip4clip_msrvtt.npy GRAM_msrvtt_tvas.npy InternVideo2_msrvtt.npy \
  --csv_path descs_ret_test_msrvtt.csv \
  --video_dir MSRVTT \
  --num_images 14 \
  --model_name OpenGVLab/InternVL3_5-38B \
  --grid_size 3 \
  --ensemble_mode soft \
  --use_subs \
  --subtitle_json msrvtt_subtitles.json \
  2>&1 | tee logs/for_testing_soft_3x3_38B_with_subs_t2v.log

# %%
# !torchrun --nproc_per_node=3 ensemble_wrapper_msrvtt_activitynet_didemo_v2t.py \
  --sim_paths clip4clip_msrvtt.npy GRAM_msrvtt_tvas.npy InternVideo2_msrvtt.npy \
  --csv_path descs_ret_test_msrvtt.csv \
  --video_dir MSRVTT \
  --num_captions 20 \
  --model_name OpenGVLab/InternVL3_5-38B \
  --grid_size 3 \
  --ensemble_mode hard_dup \
  2>&1 | tee logs/for_testing_hard_dup_3x3_38B.log

# %%
# !torchrun --nproc_per_node=3 ensemble_wrapper_msrvtt_activitynet_didemo_v2t.py \
  --sim_paths clip4clip_msrvtt.npy GRAM_msrvtt_tvas.npy InternVideo2_msrvtt.npy \
  --csv_path descs_ret_test_msrvtt.csv \
  --video_dir MSRVTT \
  --num_captions 20 \
  --model_name OpenGVLab/InternVL3_5-38B \
  --grid_size 3 \
  --ensemble_mode hard_unique \
  2>&1 | tee logs/for_testing_hard_unique_3x3_38B.log

# %%
# !torchrun --nproc_per_node=3 ensemble_wrapper_msrvtt_activitynet_didemo_v2t.py \
  --sim_paths clip4clip_msrvtt.npy GRAM_msrvtt_tvas.npy InternVideo2_msrvtt.npy \
  --csv_path descs_ret_test_msrvtt.csv \
  --video_dir MSRVTT \
  --num_captions 20 \
  --model_name OpenGVLab/InternVL3_5-38B \
  --grid_size 3 \
  --ensemble_mode soft \
  2>&1 | tee logs/for_testing_soft_3x3_38B.log

# %%
# !torchrun --nproc_per_node=3 ensemble_wrapper_msrvtt_activitynet_didemo_v2t.py \
  --sim_paths clip4clip_msrvtt.npy GRAM_msrvtt_tvas.npy InternVideo2_msrvtt.npy \
  --csv_path descs_ret_test_msrvtt.csv \
  --video_dir MSRVTT \
  --num_captions 20 \
  --model_name OpenGVLab/InternVL3_5-38B \
  --grid_size 3 \
  --ensemble_mode soft \
  --use_subs \
  --subtitle_json msrvtt_subtitles.json \
  2>&1 | tee logs/for_testing_soft_3x3_38B_with_subs.log

# %%
# !torchrun --nproc_per_node=3 wrapper_msrvtt_activitynet_didemo_t2v.py \
    --sim_path InternVideo2_msrvtt.npy \
    --csv_path descs_ret_test_msrvtt.csv \
    --video_dir MSRVTT \
    --num_images 14 \
    --model_name OpenGVLab/InternVL3_5-38B \
    --grid_size 2 \
    --use_subs \
    --subtitle_json msrvtt_subtitles.json \
    2>&1 | tee logs/InternVL3_5_38B_grid2x2_InternVideo2_MSRVTT_t2v.log

# %%
# !torchrun --nproc_per_node=3 wrapper_msrvtt_activitynet_didemo_t2v.py \
    --sim_path InternVideo2_msrvtt.npy \
    --csv_path descs_ret_test_msrvtt.csv \
    --video_dir MSRVTT \
    --num_images 14 \
    --model_name OpenGVLab/InternVL3_5-38B \
    --grid_size 2 \
    2>&1 | tee logs/InternVL3_5_38B_grid2x2_InternVideo2_MSRVTT_t2v.log

# %%
# !torchrun --nproc_per_node=3 wrapper_msrvtt_activitynet_didemo_v2t.py \
    --sim_path InternVideo2_msrvtt.npy \
    --csv_path descs_ret_test_msrvtt.csv \
    --video_dir MSRVTT \
    --num_captions 20 \
    --model_name OpenGVLab/InternVL3_5-38B \
    --grid_size 3 \
    --use_subs \
    --subtitle_json msrvtt_subtitles.json \
    2>&1 | tee logs/InternVL3_5_38B_grid3x3_InternVideo2_MSRVTT_v2t_with_subs.log

# %%
# !torchrun --nproc_per_node=3 wrapper_msrvtt_activitynet_didemo_v2t.py \
    --sim_path VAST_msrvtt.npy \
    --csv_path descs_ret_test_msrvtt.csv \
    --video_dir MSRVTT \
    --num_captions 20 \
    --model_name OpenGVLab/InternVL3_5-8B \
    --grid_size 2 \
    2>&1 | tee logs/InternVL3_5_8B_grid2x2_VAST_MSRVTT_v2t.log

# %% [markdown]
# # Vatex
#
# > The paths and everything are hard coded, you need to fix it to work on your end

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 VATEX_Wrapper_InternVL3_5_38B_grid3x3_VAST_t2v.py 2>&1 | tee logs/VATEX_InternVL3_5_38B_grid3x3_VAST_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 VATEX_Wrapper_InternVL3_5_38B_grid3x3_VAST_v2t.py 2>&1 | tee logs/VATEX_InternVL3_5_38B_grid3x3_VAST_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 VATEX_Wrapper_InternVL3_5_38B_grid3x3_Internvideo2_v2t.py 2>&1 | tee logs/VATEX_InternVL3_5_38B_grid3x3_Internvideo2_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 VATEX_Wrapper_InternVL3_5_38B_grid3x3_Internvideo2_v2t_with_subs.py 2>&1 | tee logs/VATEX_InternVL3_5_38B_grid3x3_Internvideo2_v2t_with_subs.log

# %%
# !torchrun --nproc_per_node=1 --master_port=29501 VATEX_Wrapper_InternVL3_5_38B_grid1x1_Internvideo2_t2v.py 2>&1 | tee logs/VATEX_InternVL3_5_38B_grid1x1_Internideo2_t2v.log

# %%
# !torchrun --nproc_per_node=1 --master_port=29501 VATEX_Wrapper_InternVL3_5_38B_grid2x2_Internvideo2_t2v.py 2>&1 | tee logs/VATEX_InternVL3_5_38B_grid2x2_Internideo2_t2v.log

# %%
# !torchrun --nproc_per_node=1 --master_port=29501 VATEX_Wrapper_InternVL3_5_38B_grid3x3_Internvideo2_t2v.py 2>&1 | tee logs/VATEX_InternVL3_5_38B_grid3x3_Internideo2_t2v.log

# %%
# !torchrun --nproc_per_node=1 --master_port=29501 VATEX_Wrapper_InternVL3_5_8B_grid3x3_Internvideo2_t2v.py 2>&1 | tee logs/VATEX_InternVL3_5_8B_grid3x3_Internideo2_t2v.log

# %%
# !torchrun --nproc_per_node=1 --master_port=29501 VATEX_Wrapper_InternVL3_5_14B_grid3x3_Internvideo2_t2v.py 2>&1 | tee logs/VATEX_InternVL3_5_14B_grid3x3_Internideo2_t2v.log

# %%
# !torchrun --nproc_per_node=1 --master_port=29501 VATEX_Wrapper_InternVL3_5_38B_grid4x4_Internvideo2_t2v.py 2>&1 | tee logs/VATEX_InternVL3_5_38B_grid4x4_Internideo2_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 VATEX_Wrapper_InternVL3_5_38B_grid3x3_VAST_v2t_with_subs.py 2>&1 | tee logs/VATEX_InternVL3_5_38B_grid3x3_VAST_v2t_with_subs.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 VATEX_Wrapper_InternVL3_5_38B_grid3x3_VAST_t2v_with_subs.py 2>&1 | tee logs/VATEX_InternVL3_5_38B_grid3x3_VAST_t2v_with_subs.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 VATEX_Wrapper_InternVL3_5_38B_grid3x3_Internvideo2_t2v_with_subs.py 2>&1 | tee logs/VATEX_InternVL3_5_38B_grid3x3_Internvideo2_t2v_with_subs.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 VATEX_ensemble_Wrapper_InternVL3_5_38B_grid3x3_t2v_with_subs_soft.py 2>&1 | tee logs/VATEX_ensemble_InternVL3_5_38B_grid3x3_t2v_with_subs_soft.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 VATEX_ensemble_Wrapper_InternVL3_5_38B_grid3x3_t2v_with_subs_hard_unique.py 2>&1 | tee logs/VATEX_ensemble_InternVL3_5_38B_grid3x3_t2v_with_subs_hard_unique.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 VATEX_ensemble_Wrapper_InternVL3_5_38B_grid3x3_t2v_with_subs_hard_dup.py 2>&1 | tee logs/VATEX_ensemble_InternVL3_5_38B_grid3x3_t2v_with_subs_hard_dup.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 VATEX_ensemble_Wrapper_InternVL3_5_38B_grid3x3_t2v_hard_dup.py 2>&1 | tee logs/VATEX_ensemble_InternVL3_5_38B_grid3x3_t2v_hard_dup.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 VATEX_ensemble_Wrapper_InternVL3_5_38B_grid3x3_t2v_hard_unique.py 2>&1 | tee logs/VATEX_ensemble_InternVL3_5_38B_grid3x3_t2v_hard_unique.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 VATEX_ensemble_Wrapper_InternVL3_5_38B_grid3x3_t2v_soft.py 2>&1 | tee logs/VATEX_ensemble_InternVL3_5_38B_grid3x3_t2v_soft.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 VATEX_ensemble_Wrapper_InternVL3_5_38B_grid3x3_t2v_hard_dup_with_subs.py 2>&1 | tee logs/VATEX_ensemble_InternVL3_5_38B_grid3x3_t2v_hard_dup_with_subs.log

# %% [markdown]
# # Qwen3_Grid3x3_InternVideo2_msrvtt_t2v_N_grids
# > The paths and everything are hard coded, you need to fix it to work on your end

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_Qwen3_VL_30B_A3B_Instruct_grid3x3_InternVideo2_msrvtt_v2t_10_caption.py 2>&1 | tee logs/Qwen3_VL_30B_A3B_Instruct_grid3x3_InternVideo2_msrvtt_v2t_10_caption.log

# %%
# !torchru --nproc_per_node=2 --master_port=29501 Wrapper_Qwen3_VL_30B_A3B_Instruct_grid3x3_InternVideo2_msrvtt_v2t_30_caption.py 2>&1 | tee logs/Qwen3_VL_30B_A3B_Instruct_grid3x3_InternVideo2_msrvtt_v2t_30_caption.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_Qwen3_VL_30B_A3B_Instruct_grid3x3_InternVideo2_msrvtt_v2t_20_caption.py 2>&1 | tee logs/Qwen3_VL_30B_A3B_Instruct_grid3x3_InternVideo2_msrvtt_v2t_20_caption.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_Qwen3_VL_30B_A3B_Instruct_grid3x3_InternVideo2_msrvtt_t2v_10_grids.py 2>&1 | tee logs/Qwen3_VL_30B_A3B_Instruct_grid3x3_InternVideo2_msrvtt_t2v_10_grids.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_Qwen3_VL_30B_A3B_Instruct_grid3x3_InternVideo2_msrvtt_t2v_14_grids.py 2>&1 | tee logs/Qwen3_VL_30B_A3B_Instruct_grid3x3_InternVideo2_msrvtt_t2v_14_grids.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_Qwen3_VL_30B_A3B_Instruct_grid3x3_InternVideo2_msrvtt_t2v_30_grids.py 2>&1 | tee logs/Qwen3_VL_30B_A3B_Instruct_grid3x3_InternVideo2_msrvtt_t2v_30_grids.log

# %% [markdown]
# # Gemma3_Grid3x3_InternVideo2_msrvtt_t2v_N_grids
# > The paths and everything are hard coded, you need to fix it to work on your end

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_Gemma_3_27b_it_grid3x3_InternVideo2_msrvtt_v2t_30_captions.py 2>&1 | tee logs/Gemma_3_27b_it_grid3x3_InterVideo2_msrvtt_v2t_30_caption.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_Gemma_3_27b_it_grid3x3_InternVideo2_msrvtt_v2t_20_captions.py 2>&1 | tee logs/Gemma_3_27b_it_grid3x3_InterVideo2_msrvtt_v2t_20_caption.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_Gemma_3_27b_it_grid3x3_InternVideo2_msrvtt_v2t_10_captions.py 2>&1 | tee logs/Gemma_3_27b_it_grid3x3_InterVideo2_msrvtt_v2t_10_caption.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_Gemma_3_27b_it_grid3x3_InternVideo2_msrvtt_t2v_30_grids.py 2>&1 | tee logs/Gemma_3_27b_it_grid3x3_InternVideo2_msrvtt_t2v_30_grids.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_Gemma_3_27b_it_grid3x3_InternVideo2_msrvtt_t2v_14_grids.py 2>&1 | tee logs/Gemma_3_27b_it_grid3x3_InternVideo2_msrvtt_t2v_14_grids.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_Gemma_3_27b_it_grid3x3_InternVideo2_msrvtt_t2v_10_grids.py 2>&1 | tee logs/Gemma_3_27b_it_grid3x3_InternVideo2_msrvtt_t2v_10_grids.log

# %% [markdown]
# # Everything below this point is archived
# It will still work but it is using the old hardcoded code, we recommend you use the new re facotred code shown in the first few cells of this notebook, but if you do not care, then who are we to stop you?

# %% [markdown]
# ## Ensemble_InternVL3_5_38B_grid3x3_hard_unique

# %%
#done
# !torchrun --nproc_per_node=2 --master_port=29501 ensemble_Wrapper_InternVL3_5_38B_grid3x3_hard_unique_activitynet_t2v.py 2>&1 | tee logs/ensemble_InternVL3_5_38B_grid3x3_hard_unique_activitynet_t2v.log

# %%
#done
#!torchrun --nproc_per_node=8 --master_port=29501 ensemble_Wrapper_InternVL3_5_38B_grid3x3_hard_unique_activitynet_v2t.py 2>&1 | tee logs/ensemble_InternVL3_5_38B_grid3x3_hard_unique_activitynet_v2t.log

# %%
#Done
#!torchrun --nproc_per_node=8 --master_port=29501 ensemble_Wrapper_InternVL3_5_38B_grid3x3_hard_unique_didemo_t2v.py 2>&1 | tee logs/ensemble_InternVL3_5_38B_grid3x3_hard_unique_didemo_t2v.log

# %%
#done
#!torchrun --nproc_per_node=8 --master_port=29501 ensemble_Wrapper_InternVL3_5_38B_grid3x3_hard_unique_didemo_v2t.py 2>&1 | tee logs/ensemble_InternVL3_5_38B_grid3x3_hard_unique_didemo_v2t.log

# %%
#done
#!torchrun --nproc_per_node=8 --master_port=29501 ensemble_Wrapper_InternVL3_5_38B_grid3x3_hard_unique_msrvtt_v2t_with_subs.py 2>&1 | tee logs/ensemble_InternVL3_5_38B_grid3x3_hard_unique_msrvtt_v2t_with_subs.log

# %%
#Done
#!torchrun --nproc_per_node=8 --master_port=29501 ensemble_Wrapper_InternVL3_5_38B_grid3x3_hard_unique_msrvtt_v2t.py 2>&1 | tee logs/ensemble_InternVL3_5_38B_grid3x3_hard_unique_msrvtt_v2t.log

# %%
#done
#!torchrun --nproc_per_node=8 --master_port=29501 ensemble_Wrapper_InternVL3_5_38B_grid3x3_hard_unique_msrvtt_t2v_with_subs.py 2>&1 | tee logs/ensemble_InternVL3_5_38B_grid3x3_hard_unique_msrvtt_t2v_with_subs.log

# %%
#done
#!torchrun --nproc_per_node=8 --master_port=29501 ensemble_Wrapper_InternVL3_5_38B_grid3x3_hard_unique_msrvtt_t2v.py 2>&1 | tee logs/ensemble_InternVL3_5_38B_grid3x3_hard_unique_msrvtt_t2v.log

# %% [markdown]
# ## Ensemble_InternVL3_5_38B_grid3x3_hard_dup

# %%
#done
#!torchrun --nproc_per_node=2 --master_port=29501 ensemble_Wrapper_InternVL3_5_38B_grid3x3_hard_dup_activitynet_t2v.py 2>&1 | tee logs/ensemble_InternVL3_5_38B_grid3x3_hard_dup_activitynet_t2v.log

# %%
#done
#!torchrun --nproc_per_node=2 --master_port=29501 ensemble_Wrapper_InternVL3_5_38B_grid3x3_hard_dup_activitynet_v2t.py 2>&1 | tee logs/ensemble_InternVL3_5_38B_grid3x3_hard_dup_activitynet_v2t.log

# %%
#Done
#!torchrun --nproc_per_node=2 --master_port=29501 ensemble_Wrapper_InternVL3_5_38B_grid3x3_hard_dup_didemo_t2v.py 2>&1 | tee logs/ensemble_InternVL3_5_38B_grid3x3_hard_dup_didemo_t2v.log

# %%
#Done
#!torchrun --nproc_per_node=8 --master_port=29501 ensemble_Wrapper_InternVL3_5_38B_grid3x3_hard_dup_didemo_v2t.py 2>&1 | tee logs/ensemble_InternVL3_5_38B_grid3x3_hard_dup_didemo_v2t.log

# %%
#Done
#!torchrun --nproc_per_node=8 --master_port=29501 ensemble_Wrapper_InternVL3_5_38B_grid3x3_hard_dup_msrvtt_v2t_with_subs.py 2>&1 | tee logs/ensemble_InternVL3_5_38B_grid3x3_hard_dup_msrvtt_v2t_with_subs.log

# %%
#Done
#!torchrun --nproc_per_node=8 --master_port=29501 ensemble_Wrapper_InternVL3_5_38B_grid3x3_hard_dup_msrvtt_v2t.py 2>&1 | tee logs/ensemble_InternVL3_5_38B_grid3x3_hard_dup_msrvtt_v2t.log

# %%
#Done
#!torchrun --nproc_per_node=8 --master_port=29501 ensemble_Wrapper_InternVL3_5_38B_grid3x3_hard_dup_msrvtt_t2v_with_subs.py 2>&1 | tee logs/ensemble_InternVL3_5_38B_grid3x3_hard_dup_msrvtt_t2v_with_subs.log

# %%
#done
#!torchrun --nproc_per_node=8 --master_port=29501 ensemble_Wrapper_InternVL3_5_38B_grid3x3_hard_dup_msrvtt_t2v.py 2>&1 | tee logs/ensemble_InternVL3_5_38B_grid3x3_hard_dup_msrvtt_t2v.log

# %% [markdown]
# ## Ensemble_InternVL3_5_38B_grid3x3_soft

# %%
#Done
#!torchrun --nproc_per_node=2 --master_port=29501 ensemble_Wrapper_InternVL3_5_38B_grid3x3_soft_activitynet_t2v.py 2>&1 | tee logs/ensemble_InternVL3_5_38B_grid3x3_soft_activitynet_t2v.log

# %%
# Done 
#!torchrun --nproc_per_node=2 --master_port=29501 ensemble_Wrapper_InternVL3_5_38B_grid3x3_soft_activitynet_v2t.py 2>&1 | tee logs/ensemble_InternVL3_5_38B_grid3x3_soft_activitynet_v2t.log

# %%
#Done
#!torchrun --nproc_per_node=2 --master_port=29501 ensemble_Wrapper_InternVL3_5_38B_grid3x3_soft_didemo_t2v.py 2>&1 | tee logs/ensemble_InternVL3_5_38B_grid3x3_soft_didemo_t2v.log

# %%
#Done
#!torchrun --nproc_per_node=2 --master_port=29501 ensemble_Wrapper_InternVL3_5_38B_grid3x3_soft_didemo_v2t.py 2>&1 | tee logs/ensemble_InternVL3_5_38B_grid3x3_soft_didemo_v2t.log

# %%
#Done
#!torchrun --nproc_per_node=1 --master_port=29501 ensemble_Wrapper_InternVL3_5_38B_grid3x3_soft_msrvtt_v2t_with_subs.py 2>&1 | tee logs/ensemble_InternVL3_5_38B_grid3x3_soft_msrvtt_v2t_with_subs.log

# %%
#Done
#!torchrun --nproc_per_node=1 --master_port=29501 ensemble_Wrapper_InternVL3_5_38B_grid3x3_soft_msrvtt_v2t.py 2>&1 | tee logs/ensemble_InternVL3_5_38B_grid3x3_soft_msrvtt_v2t.log

# %%
#Done
#!torchrun --nproc_per_node=1 --master_port=29501 ensemble_Wrapper_InternVL3_5_38B_grid3x3_soft_msrvtt_t2v_with_subs.py 2>&1 | tee logs/ensemble_InternVL3_5_38B_grid3x3_soft_msrvtt_t2v_with_subs.log

# %%
#Done
#!torchrun --nproc_per_node=1 --master_port=29501 ensemble_Wrapper_InternVL3_5_38B_grid3x3_soft_msrvtt_t2v.py 2>&1 | tee logs/ensemble_InternVL3_5_38B_grid3x3_soft_msrvtt_t2v.log

# %% [markdown]
# ## ActivityNet_InternVL3_5_38B_InternVideo2_activitynet

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid4x4_InternVideo2_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid4x4_InternVideo2_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid4x4_InternVideo2_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid4x4_InternVideo2_activitynet_t2v.log

# %%
# This is done
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_InternVideo2_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_InternVideo2_activitynet_v2t.log

# %%
# This is done
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_InternVideo2_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_InternVideo2_activitynet_t2v.log

# %%
# This is done
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid2x2_InternVideo2_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid2x2_InternVideo2_activitynet_v2t.log

# %%
# This is done
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid2x2_InternVideo2_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid2x2_InternVideo2_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid1x1_InternVideo2_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid1x1_InternVideo2_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=8 --master_port=29501 Wrapper_InternVL3_5_38B_grid1x1_InternVideo2_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid1x1_InternVideo2_activitynet_t2v.log

# %% [markdown]
# ## ActivityNet_InternVL3_5_14B_InternVideo2_activitynet - Only 3x3 - Set 2

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid4x4_InternVideo2_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid4x4_InternVideo2_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid4x4_InternVideo2_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid4x4_InternVideo2_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid3x3_InternVideo2_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid3x3_InternVideo2_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid3x3_InternVideo2_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid3x3_InternVideo2_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid2x2_InternVideo2_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid2x2_InternVideo2_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid2x2_InternVideo2_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid2x2_InternVideo2_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid1x1_InternVideo2_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid1x1_InternVideo2_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid1x1_InternVideo2_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid1x1_InternVideo2_activitynet_v2t.log

# %% [markdown]
# ## ActivityNet_InternVL3_5_8B_InternVideo2_activitynet - Only 3x3 - Set 2

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid4x4_InternVideo2_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid4x4_InternVideo2_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid4x4_InternVideo2_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid4x4_InternVideo2_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid3x3_InternVideo2_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid3x3_InternVideo2_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid3x3_InternVideo2_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid3x3_InternVideo2_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid2x2_InternVideo2_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid2x2_InternVideo2_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid2x2_InternVideo2_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid2x2_InternVideo2_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid1x1_InternVideo2_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid1x1_InternVideo2_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid1x1_InternVideo2_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid1x1_InternVideo2_activitynet_v2t.log

# %% [markdown]
# ## ActivityNet_InternVL3_5_38B_GRAM_activitynet - Only run 3x3 - Set 2

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid4x4_GRAM_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid4x4_GRAM_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid4x4_GRAM_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid4x4_GRAM_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_GRAM_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_GRAM_activitynet_v2t.log

# %%
# This is done
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_GRAM_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_GRAM_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid2x2_GRAM_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid2x2_GRAM_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid2x2_GRAM_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid2x2_GRAM_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid1x1_GRAM_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid1x1_GRAM_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid1x1_GRAM_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid1x1_GRAM_activitynet_t2v.log

# %% [markdown]
# ## ActivityNet_InternVL3_5_14B_GRAM_activitynet - Skipped

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid4x4_GRAM_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid4x4_GRAM_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid4x4_GRAM_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid4x4_GRAM_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid3x3_GRAM_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid3x3_GRAM_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid3x3_GRAM_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid3x3_GRAM_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid2x2_GRAM_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid2x2_GRAM_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid2x2_GRAM_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid2x2_GRAM_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid1x1_GRAM_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid1x1_GRAM_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid1x1_GRAM_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid1x1_GRAM_activitynet_v2t.log

# %% [markdown]
# ## ActivityNet_InternVL3_5_8B_GRAM_activitynet - Skipped

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid4x4_GRAM_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid4x4_GRAM_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid4x4_GRAM_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid4x4_GRAM_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid3x3_GRAM_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid3x3_GRAM_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid3x3_GRAM_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid3x3_GRAM_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid2x2_GRAM_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid2x2_GRAM_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid2x2_GRAM_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid2x2_GRAM_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid1x1_GRAM_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid1x1_GRAM_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid1x1_GRAM_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid1x1_GRAM_activitynet_v2t.log

# %% [markdown]
# ## ActivityNet_InternVL3_5_38B_clip4clip_activitynet - Only run 3x3 - Set 3

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid4x4_clip4clip_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid4x4_clip4clip_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid4x4_clip4clip_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid4x4_clip4clip_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_clip4clip_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_clip4clip_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_clip4clip_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_clip4clip_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid2x2_clip4clip_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid2x2_clip4clip_activitynet_v2t.log

# %%
# This is done
#!torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid2x2_clip4clip_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid2x2_clip4clip_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid1x1_clip4clip_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid1x1_clip4clip_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid1x1_clip4clip_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid1x1_clip4clip_activitynet_t2v.log

# %% [markdown]
# ## ActivityNet_InternVL3_5_14B_clip4clip_activitynet - Skipped

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid4x4_clip4clip_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid4x4_clip4clip_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid4x4_clip4clip_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid4x4_clip4clip_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid3x3_clip4clip_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid3x3_clip4clip_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid3x3_clip4clip_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid3x3_clip4clip_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid2x2_clip4clip_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid2x2_clip4clip_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid2x2_clip4clip_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid2x2_clip4clip_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid1x1_clip4clip_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid1x1_clip4clip_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid1x1_clip4clip_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid1x1_clip4clip_activitynet_v2t.log

# %% [markdown]
# ## ActivityNet_InternVL3_5_8B_clip4clip_activitynet - Skipped

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid4x4_clip4clip_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid4x4_clip4clip_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid4x4_clip4clip_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid4x4_clip4clip_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid3x3_clip4clip_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid3x3_clip4clip_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid3x3_clip4clip_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid3x3_clip4clip_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid2x2_clip4clip_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid2x2_clip4clip_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid2x2_clip4clip_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid2x2_clip4clip_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid1x1_clip4clip_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid1x1_clip4clip_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid1x1_clip4clip_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid1x1_clip4clip_activitynet_v2t.log

# %% [markdown]
# ## ActivityNet_InternVL3_5_38B_VAST_activitynet - Only Run 3x3 - Set 3

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid4x4_VAST_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid4x4_VAST_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid4x4_VAST_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid4x4_VAST_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_VAST_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_VAST_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_VAST_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_VAST_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid2x2_VAST_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid2x2_VAST_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid2x2_VAST_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid2x2_VAST_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid1x1_VAST_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid1x1_VAST_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid1x1_VAST_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid1x1_VAST_activitynet_v2t.log

# %% [markdown]
# ## ActivityNet_InternVL3_5_14B_VAST_activitynet - Skipped

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid4x4_VAST_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid4x4_VAST_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid4x4_VAST_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid4x4_VAST_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid3x3_VAST_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid3x3_VAST_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid3x3_VAST_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid3x3_VAST_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid2x2_VAST_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid2x2_VAST_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid2x2_VAST_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid2x2_VAST_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid1x1_VAST_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid1x1_VAST_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid1x1_VAST_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid1x1_VAST_activitynet_v2t.log

# %% [markdown]
# ## ActivityNet_InternVL3_5_8B_VAST_activitynet - Skipped

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid4x4_VAST_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid4x4_VAST_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid4x4_VAST_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid4x4_VAST_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid3x3_VAST_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid3x3_VAST_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid3x3_VAST_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid3x3_VAST_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid2x2_VAST_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid2x2_VAST_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid2x2_VAST_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid2x2_VAST_activitynet_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid1x1_VAST_activitynet_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid1x1_VAST_activitynet_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid1x1_VAST_activitynet_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid1x1_VAST_activitynet_v2t.log

# %% [markdown]
# ## DiDeMo_InternVL3_5_38B_InternVideo2_didemo - Done

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid4x4_InternVideo2_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid4x4_InternVideo2_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid4x4_InternVideo2_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid4x4_InternVideo2_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_InternVideo2_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_InternVideo2_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_InternVideo2_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_InternVideo2_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid2x2_InternVideo2_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid2x2_InternVideo2_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid2x2_InternVideo2_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid2x2_InternVideo2_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid1x1_InternVideo2_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid1x1_InternVideo2_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid1x1_InternVideo2_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid1x1_InternVideo2_didemo_t2v.log

# %% [markdown]
# ## DiDeMo_InternVL3_5_14B_InternVideo2_didemo - Done

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_14B_grid4x4_InternVideo2_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid4x4_InternVideo2_didemo_v2t.log  # DONE

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_14B_grid4x4_InternVideo2_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid4x4_InternVideo2_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_14B_grid3x3_InternVideo2_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid3x3_InternVideo2_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_14B_grid3x3_InternVideo2_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid3x3_InternVideo2_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_14B_grid2x2_InternVideo2_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid2x2_InternVideo2_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_14B_grid2x2_InternVideo2_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid2x2_InternVideo2_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_14B_grid1x1_InternVideo2_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid1x1_InternVideo2_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_14B_grid1x1_InternVideo2_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid1x1_InternVideo2_didemo_t2v.log

# %% [markdown]
# ## DiDeMo_InternVL3_5_8B_InternVideo2_didemo - Done

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid4x4_InternVideo2_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid4x4_InternVideo2_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid4x4_InternVideo2_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid4x4_InternVideo2_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid3x3_InternVideo2_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid3x3_InternVideo2_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid3x3_InternVideo2_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid3x3_InternVideo2_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid2x2_InternVideo2_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid2x2_InternVideo2_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid2x2_InternVideo2_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid2x2_InternVideo2_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid1x1_InternVideo2_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid1x1_InternVideo2_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid1x1_InternVideo2_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid1x1_InternVideo2_didemo_t2v.log

# %% [markdown]
# ## DiDeMo_InternVL3_5_38B_GRAM_didemo - Done

# %%
# !torchrun --nproc_per_node=3 --master_port=29501 Wrapper_InternVL3_5_38B_grid4x4_GRAM_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid4x4_GRAM_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=3 --master_port=29501 Wrapper_InternVL3_5_38B_grid4x4_GRAM_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid4x4_GRAM_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=3 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_GRAM_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_GRAM_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=3 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_GRAM_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_GRAM_didemo_v2t.log

# %% [markdown]
# ## DiDeMo_InternVL3_5_14B_GRAM_didemo - Done

# %%
# !torchrun --nproc_per_node=3 --master_port=29501 Wrapper_InternVL3_5_14B_grid4x4_GRAM_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid4x4_GRAM_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=3 --master_port=29501 Wrapper_InternVL3_5_14B_grid4x4_GRAM_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid4x4_GRAM_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=3 --master_port=29501 Wrapper_InternVL3_5_14B_grid3x3_GRAM_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid3x3_GRAM_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=3 --master_port=29501 Wrapper_InternVL3_5_14B_grid3x3_GRAM_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid3x3_GRAM_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=3 --master_port=29501 Wrapper_InternVL3_5_14B_grid2x2_GRAM_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid2x2_GRAM_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=3 --master_port=29501 Wrapper_InternVL3_5_14B_grid2x2_GRAM_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid2x2_GRAM_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=3 --master_port=29501 Wrapper_InternVL3_5_14B_grid1x1_GRAM_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid1x1_GRAM_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=3 --master_port=29501 Wrapper_InternVL3_5_14B_grid1x1_GRAM_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid1x1_GRAM_didemo_v2t.log

# %% [markdown]
# ## DiDeMo_InternVL3_5_8B_GRAM_didemo - Done

# %%
# !torchrun --nproc_per_node=3 --master_port=29501 Wrapper_InternVL3_5_8B_grid4x4_GRAM_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid4x4_GRAM_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=3 --master_port=29501 Wrapper_InternVL3_5_8B_grid4x4_GRAM_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid4x4_GRAM_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=3 --master_port=29501 Wrapper_InternVL3_5_8B_grid3x3_GRAM_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid3x3_GRAM_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=3 --master_port=29501 Wrapper_InternVL3_5_8B_grid3x3_GRAM_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid3x3_GRAM_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=3 --master_port=29501 Wrapper_InternVL3_5_8B_grid2x2_GRAM_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid2x2_GRAM_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=3 --master_port=29501 Wrapper_InternVL3_5_8B_grid2x2_GRAM_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid2x2_GRAM_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=3 --master_port=29501 Wrapper_InternVL3_5_8B_grid1x1_GRAM_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid1x1_GRAM_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=3 --master_port=29501 Wrapper_InternVL3_5_8B_grid1x1_GRAM_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid1x1_GRAM_didemo_v2t.log

# %% [markdown]
# ## DiDeMo_InternVL3_5_38B_clip4clip_didemo - Done

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid4x4_clip4clip_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid4x4_clip4clip_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid4x4_clip4clip_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid4x4_clip4clip_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_clip4clip_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_clip4clip_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_clip4clip_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_clip4clip_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid2x2_clip4clip_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid2x2_clip4clip_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid2x2_clip4clip_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid2x2_clip4clip_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid1x1_clip4clip_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid1x1_clip4clip_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid1x1_clip4clip_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid1x1_clip4clip_didemo_v2t.log

# %% [markdown]
# ## DiDeMo_InternVL3_5_14B_clip4clip_didemo - Done

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid4x4_clip4clip_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid4x4_clip4clip_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid4x4_clip4clip_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid4x4_clip4clip_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid3x3_clip4clip_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid3x3_clip4clip_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid3x3_clip4clip_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid3x3_clip4clip_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid2x2_clip4clip_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid2x2_clip4clip_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid2x2_clip4clip_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid2x2_clip4clip_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid1x1_clip4clip_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid1x1_clip4clip_didemo_t2v.log #8 bits

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_14B_grid1x1_clip4clip_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid1x1_clip4clip_didemo_v2t.log

# %% [markdown]
# ## DiDeMo_InternVL3_5_8B_clip4clip_didemo - Done

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid4x4_clip4clip_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid4x4_clip4clip_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid4x4_clip4clip_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid4x4_clip4clip_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid3x3_clip4clip_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid3x3_clip4clip_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid3x3_clip4clip_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid3x3_clip4clip_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid2x2_clip4clip_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid2x2_clip4clip_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid2x2_clip4clip_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid2x2_clip4clip_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid1x1_clip4clip_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid1x1_clip4clip_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid1x1_clip4clip_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid1x1_clip4clip_didemo_v2t.log

# %% [markdown]
# ## DiDeMo_InternVL3_5_38B_VAST_didemo - Done

# %%
# !torchrun --nproc_per_node=8 --master_port=29501 Wrapper_InternVL3_5_38B_grid4x4_VAST_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid4x4_VAST_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=8 --master_port=29501 Wrapper_InternVL3_5_38B_grid4x4_VAST_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid4x4_VAST_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=8 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_VAST_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_VAST_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=8 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_VAST_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_VAST_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=8 --master_port=29501 Wrapper_InternVL3_5_38B_grid2x2_VAST_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid2x2_VAST_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid2x2_VAST_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid2x2_VAST_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=8 --master_port=29501 Wrapper_InternVL3_5_38B_grid1x1_VAST_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid1x1_VAST_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=8 --master_port=29501 Wrapper_InternVL3_5_38B_grid1x1_VAST_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid1x1_VAST_didemo_t2v.log

# %% [markdown]
# ## DiDeMo_InternVL3_5_14B_VAST_didemo - Done

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_14B_grid4x4_VAST_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid4x4_VAST_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=8 --master_port=29501 Wrapper_InternVL3_5_14B_grid4x4_VAST_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid4x4_VAST_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=8 --master_port=29501 Wrapper_InternVL3_5_14B_grid3x3_VAST_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid3x3_VAST_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=8 --master_port=29501 Wrapper_InternVL3_5_14B_grid3x3_VAST_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid3x3_VAST_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=8 --master_port=29501 Wrapper_InternVL3_5_14B_grid2x2_VAST_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid2x2_VAST_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_14B_grid2x2_VAST_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid2x2_VAST_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=8 --master_port=29501 Wrapper_InternVL3_5_14B_grid1x1_VAST_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid1x1_VAST_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=8 --master_port=29501 Wrapper_InternVL3_5_14B_grid1x1_VAST_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid1x1_VAST_didemo_t2v.log

# %% [markdown]
# ## DiDeMo_InternVL3_5_8B_VAST_didemo - Done

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid4x4_VAST_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid4x4_VAST_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid4x4_VAST_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid4x4_VAST_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid3x3_VAST_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid3x3_VAST_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid3x3_VAST_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid3x3_VAST_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid2x2_VAST_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid2x2_VAST_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid2x2_VAST_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid2x2_VAST_didemo_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid1x1_VAST_didemo_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid1x1_VAST_didemo_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid1x1_VAST_didemo_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid1x1_VAST_didemo_t2v.log

# %% [markdown]
# ## MSR_VTT_InternVL3_5_38B_InternVideo2_msrvtt_30_captions_with_subs - Done

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_InternVideo2_msrvtt_v2t_30_captions_with_subs.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_InternVideo2_msrvtt_v2t_30_captions_with_subs.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid2x2_InternVideo2_msrvtt_v2t_30_captions_with_subs.py 2>&1 | tee logs/InternVL3_5_38B_grid2x2_InternVideo2_msrvtt_v2t_30_captions_with_subs.log

# %% [markdown]
# ## MSR_VTT_InternVL3_5_38B_InternVideo2_msrvtt_30_captions - Done

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_InternVideo2_msrvtt_v2t_30_captions.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_InternVideo2_msrvtt_v2t_30_captions.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid2x2_InternVideo2_msrvtt_v2t_30_captions.py 2>&1 | tee logs/InternVL3_5_38B_grid2x2_InternVideo2_msrvtt_v2t_30_captions.log

# %% [markdown]
# ## MSR_VTT_InternVL3_5_38B_GRAM_msrvtt_with_subs - Done

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_GRAM_msrvtt_v2t_with_subs.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_GRAM_msrvtt_v2t_with_subs.log # THIS IS DONE

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_GRAM_msrvtt_t2v_with_subs.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_GRAM_msrvtt_t2v_with_subs.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid2x2_GRAM_msrvtt_v2t_with_subs.py 2>&1 | tee logs/InternVL3_5_38B_grid2x2_GRAM_msrvtt_v2t_with_subs.log  # THIS IS DONE

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid2x2_GRAM_msrvtt_t2v_with_subs.py 2>&1 | tee logs/InternVL3_5_38B_grid2x2_GRAM_msrvtt_t2v_with_subs.log

# %% [markdown]
# ## MSR_VTT_InternVL3_5_38B_InternVideo2_msrvtt_with_subs - Done

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_InternVideo2_msrvtt_v2t_with_subs.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_InternVideo2_msrvtt_v2t_with_subs.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_InternVideo2_msrvtt_t2v_with_subs.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_InternVideo2_msrvtt_t2v_with_subs.log

# %% [markdown]
# ## MSR_VTT_InternVL3_5_38B_clip4clip_msrvtt_with_subs - Done#

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_clip4clip_msrvtt_v2t_with_subs.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_clip4clip_msrvtt_v2t_with_subs.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_clip4clip_msrvtt_t2v_with_subs.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_clip4clip_msrvtt_t2v_with_subs.log

# %% [markdown]
# ## MSR_VTT_InternVL3_5_38B_VAST_msrvtt_with_subs

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_VAST_msrvtt_v2t_with_subs.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_VAST_msrvtt_v2t_with_subs.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_VAST_msrvtt_t2v_with_subs.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_VAST_msrvtt_t2v_with_subs.log

# %% [markdown]
# ## MSR_VTT_InternVL3_5_38B_InternVideo2_msrvtt - Done

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid4x4_InternVideo2_msrvtt_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid4x4_InternVideo2_msrvtt_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid4x4_InternVideo2_msrvtt_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid4x4_InternVideo2_msrvtt_t2v.log  # THIS IS DOEN

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_InternVideo2_msrvtt_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_InternVideo2_msrvtt_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_InternVideo2_msrvtt_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_InternVideo2_msrvtt_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid2x2_InternVideo2_msrvtt_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid2x2_InternVideo2_msrvtt_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid2x2_InternVideo2_msrvtt_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid2x2_InternVideo2_msrvtt_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid1x1_InternVideo2_msrvtt_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid1x1_InternVideo2_msrvtt_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid1x1_InternVideo2_msrvtt_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid1x1_InternVideo2_msrvtt_t2v.log

# %% [markdown]
# ## MSR_VTT_InternVL3_5_14B_InternVideo2_msrvtt - Done

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_14B_grid4x4_InternVideo2_msrvtt_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid4x4_InternVideo2_msrvtt_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_14B_grid4x4_InternVideo2_msrvtt_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid4x4_InternVideo2_msrvtt_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_14B_grid3x3_InternVideo2_msrvtt_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid3x3_InternVideo2_msrvtt_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid3x3_InternVideo2_msrvtt_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid3x3_InternVideo2_msrvtt_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_14B_grid2x2_InternVideo2_msrvtt_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid2x2_InternVideo2_msrvtt_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_14B_grid2x2_InternVideo2_msrvtt_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid2x2_InternVideo2_msrvtt_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_14B_grid1x1_InternVideo2_msrvtt_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid1x1_InternVideo2_msrvtt_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_14B_grid1x1_InternVideo2_msrvtt_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid1x1_InternVideo2_msrvtt_t2v.log

# %% [markdown]
# ## MSR_VTT_InternVL3_5_8B_InternVideo2_msrvtt - Done

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid4x4_InternVideo2_msrvtt_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid4x4_InternVideo2_msrvtt_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid4x4_InternVideo2_msrvtt_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid4x4_InternVideo2_msrvtt_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid3x3_InternVideo2_msrvtt_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid3x3_InternVideo2_msrvtt_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid3x3_InternVideo2_msrvtt_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid3x3_InternVideo2_msrvtt_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid2x2_InternVideo2_msrvtt_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid2x2_InternVideo2_msrvtt_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid2x2_InternVideo2_msrvtt_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid2x2_InternVideo2_msrvtt_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid1x1_InternVideo2_msrvtt_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid1x1_InternVideo2_msrvtt_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid1x1_InternVideo2_msrvtt_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid1x1_InternVideo2_msrvtt_t2v.log

# %% [markdown]
# ## MSR_VTT_InternVL3_5_38B_GRAM_msrvtt_tvas - Done

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid4x4_GRAM_msrvtt_tvas_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid4x4_GRAM_msrvtt_tvas_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid4x4_GRAM_msrvtt_tvas_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid4x4_GRAM_msrvtt_tvas_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_GRAM_msrvtt_tvas_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_GRAM_msrvtt_tvas_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_GRAM_msrvtt_tvas_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_GRAM_msrvtt_tvas_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid2x2_GRAM_msrvtt_tvas_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid2x2_GRAM_msrvtt_tvas_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid2x2_GRAM_msrvtt_tvas_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid2x2_GRAM_msrvtt_tvas_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid1x1_GRAM_msrvtt_tvas_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid1x1_GRAM_msrvtt_tvas_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_38B_grid1x1_GRAM_msrvtt_tvas_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid1x1_GRAM_msrvtt_tvas_t2v.log

# %% [markdown]
# ## MSR_VTT_InternVL3_5_14B_GRAM_msrvtt_tvas - Done

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_14B_grid4x4_GRAM_msrvtt_tvas_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid4x4_GRAM_msrvtt_tvas_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_14B_grid4x4_GRAM_msrvtt_tvas_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid4x4_GRAM_msrvtt_tvas_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_14B_grid3x3_GRAM_msrvtt_tvas_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid3x3_GRAM_msrvtt_tvas_v2t.log # 8 bits

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_14B_grid3x3_GRAM_msrvtt_tvas_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid3x3_GRAM_msrvtt_tvas_t2v.log # 8 bits

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_14B_grid2x2_GRAM_msrvtt_tvas_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid2x2_GRAM_msrvtt_tvas_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_14B_grid2x2_GRAM_msrvtt_tvas_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid2x2_GRAM_msrvtt_tvas_t2v.log # 8 bits

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_14B_grid1x1_GRAM_msrvtt_tvas_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid1x1_GRAM_msrvtt_tvas_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_14B_grid1x1_GRAM_msrvtt_tvas_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid1x1_GRAM_msrvtt_tvas_t2v.log  # 8 bits

# %% [markdown]
# ## MSR_VTT_InternVL3_5_8B_GRAM_msrvtt_tvas - Done

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid4x4_GRAM_msrvtt_tvas_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid4x4_GRAM_msrvtt_tvas_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid4x4_GRAM_msrvtt_tvas_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid4x4_GRAM_msrvtt_tvas_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid3x3_GRAM_msrvtt_tvas_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid3x3_GRAM_msrvtt_tvas_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid3x3_GRAM_msrvtt_tvas_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid3x3_GRAM_msrvtt_tvas_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid2x2_GRAM_msrvtt_tvas_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid2x2_GRAM_msrvtt_tvas_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid2x2_GRAM_msrvtt_tvas_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid2x2_GRAM_msrvtt_tvas_t2v.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid1x1_GRAM_msrvtt_tvas_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid1x1_GRAM_msrvtt_tvas_v2t.log

# %%
# !torchrun --nproc_per_node=2 --master_port=29501 Wrapper_InternVL3_5_8B_grid1x1_GRAM_msrvtt_tvas_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid1x1_GRAM_msrvtt_tvas_t2v.log

# %% [markdown]
# ## MSR_VTT_InternVL3_5_38B_clip4clip_MSRVTT - Done

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid4x4_clip4clip_MSRVTT_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid4x4_clip4clip_MSRVTT_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid4x4_clip4clip_MSRVTT_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid4x4_clip4clip_MSRVTT_v2t.log #scuffed

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_clip4clip_MSRVTT_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_clip4clip_MSRVTT_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_clip4clip_MSRVTT_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_clip4clip_MSRVTT_v2t.log  #scuffed

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid2x2_clip4clip_MSRVTT_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid2x2_clip4clip_MSRVTT_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid2x2_clip4clip_MSRVTT_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid2x2_clip4clip_MSRVTT_v2t.log  #scuffed

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid1x1_clip4clip_MSRVTT_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid1x1_clip4clip_MSRVTT_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid1x1_clip4clip_MSRVTT_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid1x1_clip4clip_MSRVTT_v2t.log  #scuffed

# %% [markdown]
# ## MSR_VTT_InternVL3_5_14B_clip4clip_MSRVTT - Done

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid4x4_clip4clip_MSRVTT_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid4x4_clip4clip_MSRVTT_t2v.log  #scuffed

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid4x4_clip4clip_MSRVTT_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid4x4_clip4clip_MSRVTT_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid3x3_clip4clip_MSRVTT_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid3x3_clip4clip_MSRVTT_t2v.log #scuffed

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid3x3_clip4clip_MSRVTT_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid3x3_clip4clip_MSRVTT_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid2x2_clip4clip_MSRVTT_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid2x2_clip4clip_MSRVTT_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid2x2_clip4clip_MSRVTT_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid2x2_clip4clip_MSRVTT_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid1x1_clip4clip_MSRVTT_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid1x1_clip4clip_MSRVTT_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_14B_grid1x1_clip4clip_MSRVTT_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid1x1_clip4clip_MSRVTT_v2t.log

# %% [markdown]
# ## MSR_VTT_InternVL3_5_8B_clip4clip_MSRVTT - Done

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid4x4_clip4clip_MSRVTT_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid4x4_clip4clip_MSRVTT_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid4x4_clip4clip_MSRVTT_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid4x4_clip4clip_MSRVTT_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid3x3_clip4clip_MSRVTT_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid3x3_clip4clip_MSRVTT_t2v.log  # scuffed

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid3x3_clip4clip_MSRVTT_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid3x3_clip4clip_MSRVTT_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid2x2_clip4clip_MSRVTT_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid2x2_clip4clip_MSRVTT_t2v.log #this is scuffed

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid2x2_clip4clip_MSRVTT_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid2x2_clip4clip_MSRVTT_v2t.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid1x1_clip4clip_MSRVTT_t2v.py 2>&1 | tee logs/InternVL3_5_8B_grid1x1_clip4clip_MSRVTT_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_8B_grid1x1_clip4clip_MSRVTT_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid1x1_clip4clip_MSRVTT_v2t.log

# %% [markdown]
# ## MSR_VTT_InternVL3_5_38B_VAST_MSRVTT - Done

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid4x4_VAST_MSRVTT_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid4x4_VAST_MSRVTT_v2t.log # this is scuffed

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_VAST_MSRVTT_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_VAST_MSRVTT_v2t.log # this is scuffed

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid2x2_VAST_MSRVTT_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid2x2_VAST_MSRVTT_v2t.log # this is scuffed

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid1x1_VAST_MSRVTT_v2t.py 2>&1 | tee logs/InternVL3_5_38B_grid1x1_VAST_MSRVTT_v2t.log # this is scuffed

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid4x4_VAST_MSRVTT_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid4x4_VAST_MSRVTT_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid3x3_VAST_MSRVTT_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid3x3_VAST_MSRVTT_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid2x2_VAST_MSRVTT_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid2x2_VAST_MSRVTT_t2v.log

# %%
# !torchrun --nproc_per_node=4 --master_port=29501 Wrapper_InternVL3_5_38B_grid1x1_VAST_MSRVTT_t2v.py 2>&1 | tee logs/InternVL3_5_38B_grid1x1_VAST_MSRVTT_t2v.log

# %% [markdown]
# ## MSR_VTT_InternVL3_5_14B_VAST_MSRVTT - Done

# %%
# !torchrun --nproc_per_node=2 Wrapper_InternVL3_5_14B_grid4x4_VAST_MSRVTT_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid4x4_VAST_MSRVTT_v2t.log

# %%
# !torchrun --nproc_per_node=2 Wrapper_InternVL3_5_14B_grid3x3_VAST_MSRVTT_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid3x3_VAST_MSRVTT_v2t.log

# %%
# !torchrun --nproc_per_node=2 Wrapper_InternVL3_5_14B_grid2x2_VAST_MSRVTT_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid2x2_VAST_MSRVTT_v2t.log

# %%
# !torchrun --nproc_per_node=2 Wrapper_InternVL3_5_14B_grid1x1_VAST_MSRVTT_v2t.py 2>&1 | tee logs/InternVL3_5_14B_grid1x1_VAST_MSRVTT_v2t.log

# %%
# !torchrun --nproc_per_node=2 Wrapper_InternVL3_5_14B_grid4x4_VAST_MSRVTT_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid4x4_VAST_MSRVTT_t2v.log

# %%
# !torchrun --nproc_per_node=2 Wrapper_InternVL3_5_14B_grid3x3_VAST_MSRVTT_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid3x3_VAST_MSRVTT_t2v.log  # note this shows errors in the model

# %%
# !torchrun --nproc_per_node=2 Wrapper_InternVL3_5_14B_grid2x2_VAST_MSRVTT_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid2x2_VAST_MSRVTT_t2v.log

# %%
# !torchrun --nproc_per_node=2 Wrapper_InternVL3_5_14B_grid1x1_VAST_MSRVTT_t2v.py 2>&1 | tee logs/InternVL3_5_14B_grid1x1_VAST_MSRVTT_t2v.log

# %% [markdown]
# ## MSR_VTT_InternVL3_5_8B_VAST_MSRVTT - Done

# %%
# !torchrun --nproc_per_node=2 Wrapper_InternVL3_5_8B_grid4x4_MSRVTT_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid4x4_VAST_MSRVTT_v2t.log

# %%
# !torchrun --nproc_per_node=2 Wrapper_InternVL3_5_8B_grid3x3_MSRVTT_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid3x3_VAST_MSRVTT_v2t.log

# %%
# !torchrun --nproc_per_node=2 Wrapper_InternVL3_5_8B_grid2x2_MSRVTT_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid2x2_VAST_MSRVTT_v2t.log

# %%
# !torchrun --nproc_per_node=2 Wrapper_InternVL3_5_8B_grid1x1_MSRVTT_v2t.py 2>&1 | tee logs/InternVL3_5_8B_grid1x1_VAST_MSRVTT_v2t.log

# %%
# !torchrun --nproc_per_node=2 parallel_inference_msrvtt_8b_grid4.py 2>&1 | tee logs/t3_5_v_8b_grid4x4.log

# %%
# !torchrun --nproc_per_node=2 parallel_inference_msrvtt_8b_grid3.py 2>&1 | tee logs/t3_5_v_8b_grid3x3.log

# %%
# !torchrun --nproc_per_node=2 parallel_inference_msrvtt_8b_grid2.py 2>&1 | tee logs/t3_5_v_8b_grid2x2.log

# %%
# !torchrun --nproc_per_node=2 parallel_inference_msrvtt_8b_grid1.py 2>&1 | tee logs/t3_5_v_8b_grid1x1.log
